# %% [markdown]
# ## Visualization excercise

# %% [markdown]
# ## Import Libreries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Create a line plot

# %%
years = [2010, 2011, 2012, 2013]
sales = [100, 120, 140, 160]

# %%
plt.plot(years)

# %% [markdown]
# #### Bar chart

# %%
categories = ["Electronics", "Clothing", "Furniture"]
revenue = [250, 400, 150]

# %%
plt.bar(categories, revenue)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### Scatter Plot

# %%
hours_studied = [1,2,3,4,5]
exam_score = [50, 55, 67, 80,90]

# %%
plt.scatter(hours_studied, exam_score, color='red')
plt.title("Study hours vs exam score")
plt.xlabel("Study hours")
plt.ylabel("Exam score")
plt.legend()
plt.show()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_19352\3197357746.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.plot(years)

# %% [markdown]
# #### Bar chart

# %%
categories = ["Electronics", "Clothing", "Furniture"]
revenue = [250, 400, 150]

# %%
plt.bar(categories, revenue)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### Scatter Plot

# %%
hours_studied = [1,2,3,4,5]
exam_score = [50, 55, 67, 80,90]

# %%
plt.scatter(hours_studied, exam_score, color='red')
plt.title("Study hours vs exam score")
plt.xlabel("Study hours")
plt.ylabel("Exam score")
plt.legend()
plt.show()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_19352\3197357746.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
